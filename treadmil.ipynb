# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/My Drive/treadmil-users.csv')

# %%
dataset.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
dataset.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
dataset.shape
# Out:
# (180, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
dataset.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
dataset.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
dataset.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
dataset['Product'].nunique()
# Out:
# 3

# %%
dataset['Product'].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
dataset.groupby('Product')['Gender'].value_counts()
# Out:
# Product  Gender
# TM195    Female    40
#          Male      40
# TM498    Male      31
#          Female    29
# TM798    Male      33
#          Female     7
# Name: Gender, dtype: int64

# %%
dataset.groupby('Product')['Gender'].value_counts().plot(kind = 'bar')

# %%
dataset['Product'].value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
dataset['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
max(dataset['Income'])
# Out:
# 104581

# %%
min(dataset['Income'])
# Out:
# 29562

# %%
max(dataset['Age'])
# Out:
# 50

# %%
min(dataset['Age'])
# Out:
# 18

# %%
dataset['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
dataset['Usage'].unique()
# Out:
# array([3, 2, 4, 5, 6, 7])

# %%
dataset['Usage'].value_counts()
# Out:
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %%
dataset['Fitness'].unique()
# Out:
# array([4, 3, 2, 1, 5])

# %%
dataset['Fitness'].value_counts()
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %%
cat_col = ['Product','Gender','MaritalStatus','Education','Fitness','Usage']
for i in cat_col:
    print(i)
    print('=========')
    print(dataset[i].value_counts())
    print('')
# Out:
# Product
# ...
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64
#
# Gender
# ...
# Male      104
# Female     76
# Name: Gender, dtype: int64
#
# MaritalStatus
# ...
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64
#
# Education
# ...
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64
#
# Fitness
# ...
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64
#
# Usage
# ...
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %%
dataset['Miles'].unique()
# Out:
# array([112,  75,  66,  85,  47, 141, 103,  94, 113,  38, 188,  56, 132,
#        169,  64,  53, 106,  95, 212,  42, 127,  74, 170,  21, 120, 200,
#        140, 100,  80, 160, 180, 240, 150, 300, 280, 260, 360])

# %%
a= dataset['Miles'].unique()
a.sort()
a
# Out:
# array([ 21,  38,  42,  47,  53,  56,  64,  66,  74,  75,  80,  85,  94,
#         95, 100, 103, 106, 112, 113, 120, 127, 132, 140, 141, 150, 160,
#        169, 170, 180, 188, 200, 212, 240, 260, 280, 300, 360])

# %%
dataset['Miles'].value_counts(sort=True)
# Out:
# 85     27
# 95     12
# 66     10
# 75     10
# 47      9
# 106     9
# 94      8
# 113     8
# 53      7
# 100     7
# 180     6
# 200     6
# 56      6
# 64      6
# 127     5
# 160     5
# 42      4
# 150     4
# 38      3
# 74      3
# 170     3
# 120     3
# 103     3
# 132     2
# 141     2
# 280     1
# 260     1
# 300     1
# 240     1
# 112     1
# 212     1
# 80      1
# 140     1
# 21      1
# 169     1
# 188     1
# 360     1
# Name: Miles, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
plt.figure(figsize=(10,4))
h=sns.heatmap(dataset.isnull(),cbar=False)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
cat_col = ['Product','Gender','MaritalStatus','Education','Fitness','Usage']
sns.set_style('whitegrid')
sns.set_palette('Set2')
plt.figure(figsize=(20,15))
for i,col in enumerate(cat_col):
    plt.subplot(2,3,i+1)
    sns.countplot(x=col,data=dataset)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
num_col =['Age','Income','Miles']
plt.figure(figsize=(20,10))
for indx,col in enumerate(num_col):
    plt.subplot(2,2,indx+1)
    sns.distplot(dataset[col],kde = True,hist = False,rug = True)

# %%
dataset['Product'].value_counts(normalize=True)
# Out:
# TM195    0.444444
# TM498    0.333333
# TM798    0.222222
# Name: Product, dtype: float64

# %%
plt.figure(figsize=(10,6))
explode = (0.05, 0, 0)
_ = plt.pie(dataset['Product'].value_counts(),
            explode,
            labels=list(dataset['Product'].unique()),
            autopct='%0.1f%%',
            shadow=True)

# %%
new_col= ['Gender','MaritalStatus']
plt.figure(figsize=(10,5))
for indx,col in enumerate(new_col):
    plt.subplot(1,2,indx+1)
    plt.title(col)
    sns.countplot(x=col,data=dataset,hue='Product')
    plt.tight_layout()
    plt.xticks(rotation=45)

# %%
sns.scatterplot(x=dataset['Age'],y=dataset['Income'],s=100,data=dataset)

# %%
sns.scatterplot(x=dataset['Age'],y=dataset['Income'],hue='Gender',s=100,data=dataset)

# %%
sns.scatterplot(x=dataset['Age'],y=dataset['Income'],hue='MaritalStatus',s=100,data=dataset)

# %%
sns.stripplot(x=dataset['Gender'],y=dataset['Fitness'])

# %%
dataset.groupby([dataset['MaritalStatus']])['Fitness'].value_counts(normalize=True)*100
# Out:
# MaritalStatus  Fitness
# Partnered      3          53.271028
#                2          16.822430
#                5          16.822430
#                4          12.149533
#                1           0.934579
# Single         3          54.794521
#                5          17.808219
#                4          15.068493
#                2          10.958904
#                1           1.369863
# Name: Fitness, dtype: float64

# %%
sns.stripplot(x=dataset['Gender'],y=dataset['Usage'])

# %%
dataset.groupby([dataset['Usage']])['Gender'].value_counts(normalize=True)*100
# Out:
# Usage  Gender
# 2      Female     60.606061
#        Male       39.393939
# 3      Male       52.173913
#        Female     47.826087
# 4      Male       73.076923
#        Female     26.923077
# 5      Male       58.823529
#        Female     41.176471
# 6      Male       71.428571
#        Female     28.571429
# 7      Male      100.000000
# Name: Gender, dtype: float64

# %%
dataset.groupby([dataset['MaritalStatus'],dataset['Product']])['Product'].count()
# Out:
# MaritalStatus  Product
# Partnered      TM195      48
#                TM498      36
#                TM798      23
# Single         TM195      32
#                TM498      24
#                TM798      17
# Name: Product, dtype: int64

# %%
dataset.groupby([dataset['MaritalStatus'],dataset['Product']])['Product'].count().plot(kind='bar')

# %%
sns.catplot(x='Gender',
            y='Income', 
            hue='Product', 
            col='MaritalStatus', 
            data=dataset,
            kind='bar')

# %%
sns.relplot(x="Age", 
            y="Income", 
            hue="Product",
            sizes=(40, 400), 
            alpha=.5, 
            palette="plasma",
            height=6, 
            data=dataset).set(title='INCOME BY AGE ,PRODUCT AND')
